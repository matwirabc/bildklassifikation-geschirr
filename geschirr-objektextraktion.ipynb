# %% [raw]
# # Adaption der Objektextraktion
# Hallo! Wir wollen beliebige, selbstgewählte Objektkategorien auf Fotos (mit einfachem Hintergrund) erkennen. Sie brauchen also Fotos. Laden Sie diese auf Google-Drive hoch, oder nutzen Sie vorerst mal die [Giraffen-Puzzleteile](https://drive.google.com/drive/folders/1hXzFL_2Ot5PM3hvQCsgFhFeHV4wtG8E-?usp=drive_link). Die Daten sind auch im [dsci-Sharepoint-Ordner](https://ostch.sharepoint.com/:f:/r/teams/TS-FHS-IPM/Shared%20Documents/lehre%20und%20weiterbildung/21_Winf_MSc/10%20Module/DSCI/HS2024/Praktikum/Daten_Giraffe?csf=1&web=1&e=0OQ5db) abgelegt.
#
# Ziel dieses Notebooks ist es, den Hintergrund der Bilder so gut zu "verstehen", dass das Skript `objekt_extraction.py` anschliessend aus allen Fotos die Objekte extrahieren kann. Auf einem Foto können mehrere Objekte abgebildet sein, wir extrahieren dann aber pro Objekt ein Bild. "verstehen" bedeutet gewisse Parameterwerte zu bestimmen, mit denen die Objektextraktion zuverlässig funktioniert.
#
# Am Ende dieses Notebooks kennen wir diese Parameterwerte, und es wird das Skript `object_extraction.py` mit diesen Parameterwerten ausgeführt. Es extrahiert von allen Ihren Bildern die Ausschnitte (mit Objekten drin), welche wir für die Klassifizierung später brauchen.
#
# Die Objektextraktion im Skript object_extraction.py kann je nach Beleuchtungsverhältnissen etc. unterschiedlich gut klappen und muss allenfalls adaptiert werden. Mit diesem Notebook können die einzelnen Verarbeitungsschritte dieses Skripts detailliert nachvollzogen werden. Die Parameter, deren Werte wir bestimmen müssen, heissen:

# %%
pr = 225,400 #PREPROCESSING_RESOLUTION, --preprocessing_resolution
fr = 0.0  #FRACTION_OF_ROWS_TO_REMOVE, --fraction_of_rows_to_remove
fc = 0.0  #FRACTION_OF_COLS_TO_REMOVE, --fraction_of_cols_to_remove
vth = -140 # 0.5 #150    #VALUE_THRESHOLD, --value_threshold
es = 8     #EROSION_SIZE, --erosion_size
ds = 20     #DILATION_SIZE, --dilation_size
mpx = 4000 #MINIMUM NUMBER OF PIXELS, --minimum_number_of_pixels
Bilddateiendung = 'jpg' #Dateiendung der Bilder, ohne ".", Achtung: 'jpg' ist nicht 'JPG'
fv=255 #value_to_fill: Wert, mit dem die abgeschnittenen Ränder aufgefüllt werden sollen

# %% [markdown]
# Die angegebenen Werte sind Standardwerte, die Sie anpassen sollen.

# %% [markdown]
# ## Setup und Zugriff zu den Bilddaten

# %%
# !ls data
# Out:
# input

# %%
import sys;sys.path.append('.')
from object_extraction import *

# %%
# !ls data/input/geschirr
# Out:
# gabel-01_9638.jpg        korkenzieher-01_9716.jpg loeffel-01_9546.jpg
# gabel-01_9639.jpg        korkenzieher-01_9717.jpg messer-01_9547.jpg
# gabel-01_9640.jpg        korkenzieher-01_9718.jpg messer-01_9548.jpg
# gabel-01_9641.jpg        korkenzieher-01_9719.jpg messer-01_9549.jpg
# gabel-01_9642.jpg        korkenzieher-01_9720.jpg messer-01_9550.jpg
# gabel-01_9643.jpg        korkenzieher-01_9721.jpg messer-01_9551.jpg
# gabel-01_9644.jpg        korkenzieher-01_9722.jpg messer-01_9552.jpg
# gabel-01_9645.jpg        korkenzieher-01_9723.jpg messer-01_9553.jpg
# gabel-01_9646.jpg        korkenzieher-01_9724.jpg messer-01_9554.jpg
# gabel-01_9647.jpg        korkenzieher-01_9725.jpg messer-01_9555.jpg
# gabel-01_9648.jpg        korkenzieher-01_9726.jpg messer-01_9556.jpg
# gabel-01_9649.jpg        korkenzieher-01_9727.jpg messer-01_9557.jpg
# gabel-01_9650.jpg        korkenzieher-01_9728.jpg messer-01_9558.jpg
# gabel-01_9651.jpg        korkenzieher-01_9729.jpg messer-01_9559.jpg
# gabel-01_9652.jpg        korkenzieher-01_9730.jpg messer-01_9560.jpg
# gabel-01_9653.jpg        korkenzieher-01_9731.jpg messer-01_9561.jpg
# gabel-01_9654.jpg        korkenzieher-01_9732.jpg messer-01_9562.jpg
# gabel-01_9655.jpg        korkenzieher-01_9733.jpg messer-01_9563.jpg
# gabel-01_9656.jpg        korkenzieher-01_9734.jpg messer-01_9564.jpg
# gabel-01_9657.jpg        loeffel-01_9504.jpg      messer-01_9565.jpg
# gabel-01_9658.jpg        loeffel-01_9505.jpg      messer-01_9566.jpg
# gabel-01_9659.jpg        loeffel-01_9506.jpg      messer-01_9567.jpg
# gabel-01_9660.jpg        loeffel-01_9507.jpg      messer-01_9568.jpg
# gabel-01_9661.jpg        loeffel-01_9508.jpg      messer-01_9569.jpg
# gabel-01_9662.jpg        loeffel-01_9509.jpg      messer-01_9570.jpg
# gabel-01_9663.jpg        loeffel-01_9510.jpg      messer-01_9572.jpg
# gabel-01_9664.jpg        loeffel-01_9511.jpg      messer-01_9573.jpg
# gabel-01_9665.jpg        loeffel-01_9512.jpg      messer-01_9574.jpg
# gabel-01_9666.jpg        loeffel-01_9513.jpg      messer-01_9575.jpg
# gabel-01_9667.jpg        loeffel-01_9514.jpg      messer-01_9576.jpg
# gabel-01_9668.jpg        loeffel-01_9515.jpg      messer-01_9577.jpg
# gabel-01_9669.jpg        loeffel-01_9516.jpg      messer-01_9578.jpg
# gabel-01_9670.jpg        loeffel-01_9517.jpg      messer-01_9579.jpg
# gabel-01_9671.jpg        loeffel-01_9518.jpg      messer-01_9580.jpg
# gabel-01_9672.jpg        loeffel-01_9519.jpg      messer-01_9581.jpg
# gabel-01_9673.jpg        loeffel-01_9520.jpg      messer-01_9582.jpg
# gabel-01_9674.jpg        loeffel-01_9521.jpg      messer-01_9583.jpg
# gabel-01_9675.jpg        loeffel-01_9522.jpg      messer-01_9584.jpg
# gabel-01_9676.jpg        loeffel-01_9523.jpg      messer-01_9585.jpg
# gabel-01_9677.jpg        loeffel-01_9524.jpg      messer-01_9586.jpg
# gabel-01_9678.jpg        loeffel-01_9525.jpg      messer-01_9587.jpg
# gabel-01_9679.jpg        loeffel-01_9527.jpg      trinkhalm-01_9682.jpg
# gabel-01_9680.jpg        loeffel-01_9528.jpg      trinkhalm-01_9683.jpg
# gabel-01_9681.jpg        loeffel-01_9529.jpg      trinkhalm-01_9684.jpg
# korkenzieher-01_9700.jpg loeffel-01_9530.jpg      trinkhalm-01_9685.jpg
# korkenzieher-01_9701.jpg loeffel-01_9531.jpg      trinkhalm-01_9686.jpg
# korkenzieher-01_9702.jpg loeffel-01_9532.jpg      trinkhalm-01_9687.jpg
# korkenzieher-01_9703.jpg loeffel-01_9533.jpg      trinkhalm-01_9688.jpg
# korkenzieher-01_9704.jpg loeffel-01_9534.jpg      trinkhalm-01_9689.jpg
# korkenzieher-01_9705.jpg loeffel-01_9535.jpg      trinkhalm-01_9690.jpg
# korkenzieher-01_9706.jpg loeffel-01_9536.jpg      trinkhalm-01_9691.jpg
# korkenzieher-01_9707.jpg loeffel-01_9537.jpg      trinkhalm-01_9692.jpg
# korkenzieher-01_9708.jpg loeffel-01_9538.jpg      trinkhalm-01_9693.jpg
# korkenzieher-01_9709.jpg loeffel-01_9539.jpg      trinkhalm-01_9694.jpg
# korkenzieher-01_9710.jpg loeffel-01_9540.jpg      trinkhalm-01_9695.jpg
# korkenzieher-01_9711.jpg loeffel-01_9541.jpg      trinkhalm-01_9696.jpg
# korkenzieher-01_9712.jpg loeffel-01_9542.jpg      trinkhalm-01_9697.jpg
# korkenzieher-01_9713.jpg loeffel-01_9543.jpg      trinkhalm-01_9698.jpg
# korkenzieher-01_9714.jpg loeffel-01_9544.jpg      trinkhalm-01_9699.jpg
# korkenzieher-01_9715.jpg loeffel-01_9545.jpg

# %% [markdown]
# Wenn das geklappt hat, haben Sie Zugriff auf die Daten! In der nächsten Zelle muss einfach der Pfad richtig angepasst werden. Dann sind Sie gerüstet für den Rest des Notebooks. Kopieren Sie jenen Pfad als String in die folgende Variable:

# %%
from pathlib import Path #Path ist eien Klasse, welche den Umgang mit Dateipfaden erleichtert
pfad_zu_daten_string = 'data/input/geschirr'

pfad_zu_daten = Path(pfad_zu_daten_string)

pfad_zu_object_extraction =  Path('.')

# %% [markdown]
# Als nächstes benötigen wir den Pfad zu `lcl_colab/1_object_extraction`. Er muss in sys.path zu finden sein. In der nächsten Zelle wird dies getestet:

# %% [markdown]
# Nun sollte die Datei `object_extraction.py` gefunden werden und das Modul object_extraction importiert werden können

# %%
from object_extraction import *

# %% [markdown]
# Laden wir ein Bild!

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

def show_image(im):
    imshow(im)
    ax = plt.gca()
    ax.set_xticks([]); ax.set_yticks([]);
    return ax

def choose_an_image():
    """
    Wähle eine Datei aus <pfad_zu_daten> und stelle es dar
    """
    Bilddatei_Liste = pd.Series(pfad_zu_daten.iterdir())
    fn = Bilddatei_Liste.sample(1).values[0]
    im = load_file(fn)
    return im

im = choose_an_image()
show_image(im)
# Out:
# <Axes: >

# %% [markdown]
# # Adaption der Parameter
# Wir haben Zugriff auf die Bilddaten, nun möchten wir die Parameterwerte auswählen, welche die Objekte gut vom Hintergrund isolieren. Die Funktion `process_file` erledigt das.
#
# Das Vorgehen dabei ist Folgendes:
# 1. Lade das Bild und reduziere die Auflösung: Parameter **`pr`** enthält ein Tupel mit der Anzahl Pixelzeilen und der Anzahl Pixelspalten. Dies dient hauptsächlich der Beschleunigung der weiteren Verarbeitung.
# 2. Schneide jeweils an den Rändern einen Prozentsatz der Zeilen bzw. Spalten ab: Der Prozentsatz der Zeilen ist durch **`fr`**, jener der Spalten durch **`fc`** gegeben.
# 3. Es wird ein Schwellwert auf den value-Wert (in der hsv-Farbdarstellung) angewendet, um den dunklen (`sign`=+1) oder hellen (`sign`=-1) Hintergrund zu erkennen. Dies ergibt eine Maske (binärer Array), welcher Vordergrundpixel identifiziert.
# 4. Es werden kleine Artefakte auf der Maske durch Erosion und Dilatation entfernt. Die Parameter `es` und `ds` geben die Grössen der Erosions- und Dilatationsmasken an.
# 5. Die Objekte werden ausgeschnitten, d.h. separate Objekte werden identifiziert, und um jedes Objekt wird eine enge rechteckige *Bounding Box* gesetzt.
# 6. Sollte der Ausschnitt weniger als **`mpx`** Pixel enthalten, wird er verworfen. Dies ist nötig, weil manchmal Reflexionen o.ä. zusätzliche kleine Ausschnitte erzeugen, welche aber nicht ein Objekt enthalten.
# 7. Ein neues Bild wird abgespeichert, welches nur noch das (ausgeschnittene) Bildelement enthält.
#
#
# Wenn dies gelingt, sind die Bilder in einer geeigneten Form für Deep Learning.
#
# Im Folgenden wird dieser Vorgang für ein (von Ihnen gewähltes) Bild durchgeführt. Passen Sie die Parameter so an, dass die Extraktion gut gelingt.
# Die Parameter sollten Sie hier anpassen:

# %% [markdown]
# ### Schritt 0: Laden des Bildes

# %%
show_image(im);

# %% [markdown]
# Das Bild hat aktuell die Auflösung

# %%
im.shape
# Out:
# (3024, 4032, 3)

# %% [markdown]
# ### Schritt 1: Auflösungsreduktion

# %% [markdown]
# Die Bilder können zu hoch aufgelöst sein für unsere Anwendung, wodurch sich die Rechenzeit der folgenden Operationen vervielfacht. Die Vorverarbeitungsroutine `object_extraction.py` beginnt daher damit, mit der `--preprocessing_resolution` (oder `-pr`) das Bild zu verkleinern:

# %%
im_resized = (255*resize(im,pr)).astype('uint8')
show_image(im_resized);

# %% [markdown]
# Die Auflösung sollte nun Ihren Wünschen entsprechen (`NrRows`, `NrCols`, Anzahl Farbkanäle):

# %%
im_resized.shape
# Out:
# (225, 400, 3)

# %% [markdown]
# ## Schritt 2: Ränder abschneiden
# Als nächstes müssen ev. die Ränder des Bildes überdeckt werden. Damit können Artefakte beseitigt werden, z.B. wenn der schwarze Hintergrund nicht bis an den Rand des Bildes reicht. `fraction_of_rows_to_remove` und `fraction_of_cols_to_remove` geben an, wieviel abgeschnitten wird. Aufgefüllt werden die Pixel mit dem Wert `value_to_fill=0` (in allen Farbkanälen).

# %%
im_filled = fill_borders(im_resized,value_to_fill=fv,fraction_of_rows_to_remove=fr,
                         fraction_of_cols_to_remove=fc)
show_image(im_filled);

# %% [markdown]
# **Aufgabe 1:** Finden Sie für Ihre Bilder passende Werte für `fraction_of_rows_to_remove` und `fraction_of_cols_to_remove`.

# %% [markdown]
# ### Schritt 3: Hintergrundschwellwert bestimmen
# Wählen Sie zunächst sign=+1 für Schwarzen Hintergrund oder sign=-1 für weissen Hintergrund.

# %% [markdown]
# Als nächstes soll ein Schwellwert im Farbraum das Objekt vom Hintergrund isolieren. Wir arbeiten im *hsv*-Raum: hue, saturation und value sind die drei Farbdimensionen, für welche jeweils ein Mindestwert (für sign=+1) bzw. Maximalwert (für sign=-1) für Vordergrundpixel festgelegt werden kann. Berechnet wird konkret: `mask = sign*im_hsv[:,:,2]>value_schwellwert*sign` (etc.).

# %%
mask = generate_mask_with_hsv_threshold(im_filled, hue_threshold=None,saturation_threshold=None,
                                        value_threshold=vth)
print("Mask shape:", mask)
plt.figure();show_image(mask);

masked_image = create_masked_image(im_filled,mask)
plt.figure();show_image(masked_image);
# Out:
# Mask shape: [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]

# %% [markdown]
# **Aufgabe 2:** Finden Sie Werte für `hue_schwellwert`, `saturation_schwellwert` und `value_schwellwert` so, dass die Maske möglichst gut zum Objektumriss passt. Bei der Wahl der Schwellwerte muss man aufpassen, dass sie nicht nur auf diesem einen Bild passen, sondern auch auf allen anderen!

# %%
help(generate_mask_with_hsv_threshold)
# Out:
# Help on function generate_mask_with_hsv_threshold in module object_extraction:
#
# generate_mask_with_hsv_threshold(im, sign=None, hue_threshold=None, saturation_threshold=None, value_threshold=None)
#     Erstelle eine Maske des Bildes (aktuell mit einem Schwellwert auf dem Value-Kanal des Bildes).

# %% [markdown]
# ## Schritt 4: Erosion und Dilatationsfilgergrössen bestimmen

# %%
## Diese Methode war noch nicht gegeben (??)
def morphology_transform(mask, shape=square, erosion_size=5, dilation_size=10):
    # Remove small noise pixels
    morphed = erosion(mask, shape(erosion_size))
    # Expand the mask to cover the full object
    morphed = dilation(morphed, shape(dilation_size))
    return morphed

# %% [markdown]
# Wenn Hintergrundregionen übrigbleiben, dann ergibt dies zusätzliche Trainingsbilder, welche nicht einer Klasse zugeordnet sind- und es kostet auch viel Rechenzeit. Kleine, isolierte Maskenpixel möchten wir daher als nächstes durch Erosion entfernen.

# %% [markdown]
# **Aufgabe 3:** Finden Sie Werte für es und ds, welche möglichst keine vereinzelte Hintergrundpixel in der Maske übrig lassen:

# %%
morphed_mask = morphology_transform(mask,shape = square,erosion_size=es,dilation_size=ds)
show_image(morphed_mask);

# %% [markdown]
# Ev. haben Sie auch Glück, und Sie sehen oben nur eine einzige zusammenhängende gelbe Struktur? Dann können Sie die Werte so lassen, wie sie sind!

# %% [markdown]
# `create_mask` ist nun einfach eine Routine, welche die obigen Schritte der Maskenbildung zusammenfasst. Sie sollte das gleiche Bild `morphed_mask` wie oben erstellen:

# %%
## Diese Methode war noch nicht gegeben (??)
def create_mask(im, fraction_of_rows_to_remove=0, fraction_of_cols_to_remove=0, 
                hue_threshold=None, saturation_threshold=None, value_threshold=150, 
                erosion_size=5, dilation_size=10):
    """
    Creates a cleaned binary mask for object extraction.
    
    Args:
        im: The input RGB image.
        fraction_of_rows_to_remove: Percentage of rows to fill at the top/bottom.
        fraction_of_cols_to_remove: Percentage of columns to fill at the sides.
        hue_threshold: Threshold for the Hue channel (optional).
        saturation_threshold: Threshold for the Saturation channel (optional).
        value_threshold: Threshold for the Value (brightness) channel.
        erosion_size: Size of the square for the erosion operation.
        dilation_size: Size of the square for the dilation operation.
        
    Returns:
        morphed_mask: The final processed binary mask.
        im_filled: The image with borders filled.
    """
    # Schritt 1: Ränder auffüllen (Borders removal/filling)
    # Filling borders with a value (usually 0) to remove background artifacts.
    im_filled = fill_borders(im, value_to_fill=0, 
                             fraction_of_rows_to_remove=fraction_of_rows_to_remove, 
                             fraction_of_cols_to_remove=fraction_of_cols_to_remove)
    
    # Schritt 2: Maskengenerierung (HSV Thresholding)
    # Isolate foreground pixels based on brightness (Value) in HSV space.
    mask = generate_mask_with_hsv_threshold(im_filled,
                                            hue_threshold=hue_threshold, 
                                            saturation_threshold=saturation_threshold, 
                                            value_threshold=value_threshold)
    
    # Schritt 3: Morphologische Transformation (Cleaning)
    # Remove small artifacts (erosion) and close gaps in objects (dilation).
    morphed_mask = morphology_transform(mask, shape=square, 
                                        erosion_size=erosion_size, 
                                        dilation_size=dilation_size)
    
    return morphed_mask, im_filled

# %%
morphed_mask,im_filled  = create_mask(im_resized,
                                      fraction_of_rows_to_remove=fr,fraction_of_cols_to_remove=fc,
                                      hue_threshold=None,saturation_threshold=None,value_threshold=vth,
                                      erosion_size=es,dilation_size=ds)
show_image(morphed_mask);

# %% [markdown]
# Nun wird die Maske benutzt, um das Objekt (oder die Objekte) aus dem Bild auszuschneiden:

# %%
masked_image = create_masked_image(im_filled,morphed_mask)
show_image(masked_image);
masked_image.shape
# Out:
# (225, 400, 3)

# %% [markdown]
# Hier sollte ein Bild zu sehen sein, welches einen komplett schwarzen Hintergrund hat, und nur die relevanten Objekte zeigt. Als nächstes hätten wir gerne von jedem Objekt ein separates Bild, so dass wir darauf unseren Bildklassifikator trainieren können.

# %% [markdown]
# ## Schritt 5: Objekte ausschneiden
# Wir haben den Hintergrund eliminiert. Damit ist es nun leichter, die Objekte voneinander zu trennen. Eine Funktion von [scikit-image](https://scikit-image.org/docs/stable/api/skimage.measure.html#skimage.measure.label) tut dies:

# %%
from skimage.measure import label
label_img = label(morphed_mask)
show_image(label_img)
plt.colorbar();

# %% [markdown]
# Falls das obige Bild wie eine Maske aussieht: Vermutlich liegt nur ein Bild vor- deren Pixel wird dann mit dem Wert "1" aufgefüllt. Wäre ein zweites Objekt vorhanden, würde dieses mit dem Wert "2" aufgefüllt und wäre in einer leicht anderen Farbe sichtbar. Aus diesem gelabelten Bild werden nun Teilbilder extrahiert, welche jeweils nur ein Objekt enthalten:

# %%
label_img.shape,masked_image.shape
# Out:
# ((225, 400), (225, 400, 3))

# %%
regionlist,regions = extract_regions(label_img,masked_image,fraction_of_rows_to_remove=fr)
len(regionlist)
# Out:
# 1

# %% [markdown]
# Alle obigen Schritte sind in der Funktion image_preprocessing zusammengefasst:

# %%
## Diese Methode war noch nicht gegeben (??)
def image_preprocessing(im, 
                        fraction_of_rows_to_remove=0, 
                        fraction_of_cols_to_remove=0, 
                        value_threshold=150, 
                        erosion_size=5, 
                        dilation_size=10, 
                        pr=(225, 400)):
    """
    Complete pipeline to process a single image and extract object regions.
    
    Args:
        im: Raw input image (numpy array).
        fraction_of_rows_to_remove: Vertical border padding.
        fraction_of_cols_to_remove: Horizontal border padding.
        value_threshold: Brightness threshold for HSV mask.
        erosion_size: Pixel size for mask cleanup.
        dilation_size: Pixel size for mask expansion.
        pr: Tuple defining the target resolution (height, width).
        
    Returns:
        regionlist: List of intensity images of the extracted objects.
        regions: List of region properties (metadata).
        mask: The cleaned binary mask used for extraction.
        masked_image: The rescaled image with background zeroed out.
    """
    
    # 1. Schritt: Auflösungsreduktion (Resizing)
    # Scales the image to speed up subsequent processing.
    # Note: We scale back to 0-255 uint8 to match standard image formats.
    im_resized = (255 * resize(im, pr)).astype('uint8')
    
    # 2. & 3. Schritt: Maskenerstellung (Border removal, Thresholding, & Morphology)
    # Combines border filling and HSV masking into one binary array.
    mask, im_filled = create_mask(
        im_resized,
        fraction_of_rows_to_remove=fraction_of_rows_to_remove,
        fraction_of_cols_to_remove=fraction_of_cols_to_remove,
        hue_threshold=None,
        saturation_threshold=None,
        value_threshold=value_threshold,
        erosion_size=erosion_size,
        dilation_size=dilation_size
    )
    
    # 4. Schritt: Hintergrund eliminieren (Masking)
    # Applies the mask to the image, keeping only the object pixels.
    masked_image = create_masked_image(im_filled, mask)
    
    # 5. Schritt: Objekte identifizieren (Labeling)
    # Assigns a unique ID to each disconnected group of pixels in the mask.
    label_img = label(mask)
    
    # 6. Schritt: Objekte ausschneiden (Region Extraction)
    # Isolates individual objects and creates their bounding boxes.
    regionlist, regions = extract_regions(
        label_img, 
        masked_image, 
        fraction_of_rows_to_remove=fraction_of_rows_to_remove
    )
    
    return regionlist, regions, mask, masked_image

# %%
regionlist,regions,mask,masked_image = image_preprocessing(im,
                                                           fraction_of_rows_to_remove=fr,
                                                           fraction_of_cols_to_remove=fc,
                                                           value_threshold=vth,
                                                           erosion_size=es,dilation_size=ds)
print(f"Anzahl gefundene Bereiche: {len(regionlist)}")
# Out:
# Anzahl gefundene Bereiche: 1

# %%
label_img.shape,masked_image.shape,len(regions)
# Out:
# ((225, 400), (225, 400, 3), 1)

# %%
show_image(masked_image)
# Out:
# <Axes: >

# %% [markdown]
# ## Schritt 6: Kleine Objekte (Artefakte) ignorieren
# Manchmal sind einige der gefundenen Regionen viel zu klein, um echte Objekte zu sein. Es gibt eine Option `--minimum-number-of-pixels` bzw. `-mpx`, welche Regionen unterdrückt, welche zu klein sind. Die Grösse der Regionen wird hier ausgegeben, um diesen Parameter gut einstellen zu können.

# %%
if len(regions)<10:
    for ireg,reg in enumerate(regions):
        print(f"Region {ireg}: {int(reg.area):>6}")
else:
    #for ireg,reg in enumerate(regions):
    #    print(f"{int(reg.area):<3} ",end='')

    plt.hist([reg.area for reg in regions],bins=np.logspace(1,6,100))
    plt.gca().set_xscale('log') #ev. sieht man damit etwas mehr
    plt.gca().set_yscale('log')
# Out:
# Region 0:  15855

# %% [markdown]
# Schauen wir uns die extrahierten Regionen an - es sollten nicht zu viele sein.

# %% [markdown]
# **Aufgabe 4:** Bestimmen Sie einen geeigneten Wert von `mpx`, so dass nur relevante Regionen übrig bleiben. Tragen Sie den Wert in die Parameterliste ein.
#
# Der `mpx`-Wert wird in der nächsten Zelle verwendet:

# %%
relevante_regionen =  [reg for reg in regions if reg.area >= mpx]
if len(relevante_regionen)<20:
    for reg in relevante_regionen:
        plt.figure();
        plt.imshow(reg.image_intensity);
        plt.xticks([]);plt.yticks([]) # Wir brauchen keine x- und y-Achse
else:
    print(f"Das würde {len(relevante_regionen)} Graphiken erzeugen! Ich mache lieber nichts...")

# %% [markdown]
# Sehen Sie hier Ihre extrahierten Objekte, und keine (oder nur wenige) Artefakte?
# Ja?
# Wirklich?
# **Cool!**
# Dann können wir nun versuchen, alle weiteren Daten zu verarbeiten. Das kann  in der Kommandozeile wie folgt erreicht werden:

# %%
Ausgabepfad = Path('output/geschirr/1_object_extraction_output')
# Ausgabepfad.mkdir(mode=644,exist_ok=True) # my had to change this otherwise permission error
Ausgabepfad.mkdir(mode=0o755, parents=True, exist_ok=True)
Ausgabepfad
# Out:
# PosixPath('output/geschirr/1_object_extraction_output')

# %%
imgfns = list(Path('data/input/geschirr/').glob('*.'+Bilddateiendung))
imgfns[:5]
# Out:
# [PosixPath('data/input/geschirr/messer-01_9554.jpg'),
#  PosixPath('data/input/geschirr/messer-01_9568.jpg'),
#  PosixPath('data/input/geschirr/messer-01_9583.jpg'),
#  PosixPath('data/input/geschirr/gabel-01_9638.jpg'),
#  PosixPath('data/input/geschirr/korkenzieher-01_9732.jpg')]

# %%
yta = True #args.yes_to_all
outputpath= Ausgabepfad
outputpath_Ausschnitte = os.path.join(outputpath,'Ausschnitte')
ask_path_creation(outputpath_Ausschnitte,yes_to_all=yta)

fraction_of_rows_to_remove = float(fr)
fraction_of_cols_to_remove = float(fc)
preprocessing_resolution = [int(f) for f in pr]
print('preprocessing_resolution ',preprocessing_resolution )
erosion_size= intOrNone(es)
dilation_size= intOrNone(ds)
hue_threshold = None#intOrNone(hth)
value_threshold = vth#None#intOrNone(vth)
saturation_threshold = None #intOrNone(sth)
write_summary_file = False
num_cores = 1 #int(args.num_cores)
minimum_number_of_pixels = int(mpx)

kwargs = {'fraction_of_rows_to_remove':fr,'fraction_of_cols_to_remove':fc,'hue_threshold':hue_threshold,'saturation_threshold':saturation_threshold,'value_threshold':vth,
        'erosion_size':erosion_size,'dilation_size':dilation_size,'min_num_pixels':minimum_number_of_pixels,'outputpath':outputpath_Ausschnitte,'preprocessing_resolution':preprocessing_resolution}
# Out:
# INFO:object_extraction:Der Pfad output/geschirr/1_object_extraction_output/Ausschnitte existiert bereits.
# preprocessing_resolution  [225, 400]

# %%
NrFilesToProcess = None # None eingeben für alle
kwargs['num_cores']=1
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
main(imgfns[:NrFilesToProcess],kwargs)
# Out:
#   0% (0 of 179) |                        | Elapsed Time: 0:00:00 ETA:  --:--:--INFO:object_extraction:Shapes of extracted regions: [(201, 274, 3)]
#   0% (1 of 179) |                        | Elapsed Time: 0:00:00 ETA:   0:02:35INFO:object_extraction:Shapes of extracted regions: [(184, 333, 3)]
#   1% (2 of 179) |                        | Elapsed Time: 0:00:01 ETA:   0:02:35INFO:object_extraction:Shapes of extracted regions: [(150, 315, 3)]
#   1% (3 of 179) |                        | Elapsed Time: 0:00:02 ETA:   0:02:32INFO:object_extraction:Shapes of extracted regions: [(110, 354, 3)]
#   2% (4 of 179) |                        | Elapsed Time: 0:00:03 ETA:   0:02:31INFO:object_extraction:Shapes of extracted regions: [(155, 335, 3), (57, 38, 3)]
# INFO:object_extraction:skipping region: num_pix=1618,shape:(57, 38, 3),area:1618.0, as num_pix is < 7000
#   2% (5 of 179) |                        | Elapsed Time: 0:00:04 ETA:   0:02:31INFO:object_extraction:Shapes of extracted regions: [(191, 231, 3)]
#   3% (6 of 179) |                        | Elapsed Time: 0:00:05 ETA:   0:02:30INFO:object_extraction:Shapes of extracted regions: [(173, 277, 3)]
#   3% (7 of 179) |                        | Elapsed Time: 0:00:06 ETA:   0:02:29INFO:object_extraction:Shapes of extracted regions: [(184, 316, 3), (69, 48, 3)]
# INFO:object_extraction:skipping region: num_pix=2036,shape:(69, 48, 3),area:2036.0, as num_pix is < 7000
#   4% (8 of 179) |#                       | Elapsed Time: 0:00:06 ETA:   0:02:28INFO:object_extraction:Shapes of extracted regions: [(126, 350, 3)]
#   5% (9 of 179) |#                       | Elapsed Time: 0:00:07 ETA:   0:02:27INFO:object_extraction:Shapes of extracted regions: [(142, 311, 3)]
#   5% (10 of 179) |#                      | Elapsed Time: 0:00:08 ETA:   0:02:26INFO:object_extraction:Shapes of extracted regions: [(170, 332, 3)]
#   6% (11 of 179) |#                      | Elapsed Time: 0:00:09 ETA:   0:02:25INFO:object_extraction:Shapes of extracted regions: [(213, 228, 3)]
#   6% (12 of 179) |#                      | Elapsed Time: 0:00:10 ETA:   0:02:24INFO:object_extraction:Shapes of extracted regions: [(153, 304, 3)]
#   7% (13 of 179) |#                      | Elapsed Time: 0:00:11 ETA:   0:02:23INFO:object_extraction:Shapes of extracted regions: [(157, 383, 3)]
#   7% (14 of 179) |#                      | Elapsed Time: 0:00:12 ETA:   0:02:23INFO:object_extraction:Shapes of extracted regions: [(214, 85, 3)]
#   8% (15 of 179) |#                      | Elapsed Time: 0:00:12 ETA:   0:02:22INFO:object_extraction:Shapes of extracted regions: [(207, 193, 3)]
#   8% (16 of 179) |##                     | Elapsed Time: 0:00:13 ETA:   0:02:21INFO:object_extraction:Shapes of extracted regions: [(131, 326, 3), (64, 27, 3)]
# INFO:object_extraction:skipping region: num_pix=1548,shape:(64, 27, 3),area:1548.0, as num_pix is < 7000
#   9% (17 of 179) |##                     | Elapsed Time: 0:00:14 ETA:   0:02:20INFO:object_extraction:Shapes of extracted regions: [(135, 327, 3), (41, 31, 3)]
# INFO:object_extraction:skipping region: num_pix=1045,shape:(41, 31, 3),area:1045.0, as num_pix is < 7000
#  10% (18 of 179) |##                     | Elapsed Time: 0:00:15 ETA:   0:02:19INFO:object_extraction:Shapes of extracted regions: [(221, 128, 3)]
#  10% (19 of 179) |##                     | Elapsed Time: 0:00:16 ETA:   0:02:18INFO:object_extraction:Shapes of extracted regions: [(206, 84, 3)]
#  11% (20 of 179) |##                     | Elapsed Time: 0:00:17 ETA:   0:02:17INFO:object_extraction:Shapes of extracted regions: [(18, 25, 3), (172, 376, 3), (13, 14, 3)]
# INFO:object_extraction:skipping region: num_pix=385,shape:(18, 25, 3),area:385.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=178,shape:(13, 14, 3),area:178.0, as num_pix is < 7000
#  11% (21 of 179) |##                     | Elapsed Time: 0:00:18 ETA:   0:02:16INFO:object_extraction:Shapes of extracted regions: [(207, 266, 3)]
#  12% (22 of 179) |##                     | Elapsed Time: 0:00:19 ETA:   0:02:16INFO:object_extraction:Shapes of extracted regions: [(60, 253, 3), (25, 37, 3)]
# INFO:object_extraction:skipping region: num_pix=869,shape:(25, 37, 3),area:869.0, as num_pix is < 7000
#  12% (23 of 179) |##                     | Elapsed Time: 0:00:19 ETA:   0:02:15INFO:object_extraction:Shapes of extracted regions: [(14, 23, 3), (69, 311, 3)]
# INFO:object_extraction:skipping region: num_pix=292,shape:(14, 23, 3),area:292.0, as num_pix is < 7000
#  13% (24 of 179) |###                    | Elapsed Time: 0:00:20 ETA:   0:02:14INFO:object_extraction:Shapes of extracted regions: [(209, 103, 3)]
#  13% (25 of 179) |###                    | Elapsed Time: 0:00:21 ETA:   0:02:13INFO:object_extraction:Shapes of extracted regions: [(159, 325, 3), (56, 34, 3)]
# INFO:object_extraction:skipping region: num_pix=1446,shape:(56, 34, 3),area:1446.0, as num_pix is < 7000
#  14% (26 of 179) |###                    | Elapsed Time: 0:00:22 ETA:   0:02:12INFO:object_extraction:Shapes of extracted regions: [(105, 302, 3)]
#  15% (27 of 179) |###                    | Elapsed Time: 0:00:23 ETA:   0:02:11INFO:object_extraction:Shapes of extracted regions: [(126, 315, 3)]
#  15% (28 of 179) |###                    | Elapsed Time: 0:00:24 ETA:   0:02:10INFO:object_extraction:Shapes of extracted regions: [(212, 87, 3)]
#  16% (29 of 179) |###                    | Elapsed Time: 0:00:25 ETA:   0:02:10INFO:object_extraction:Shapes of extracted regions: [(15, 24, 3), (193, 305, 3)]
# INFO:object_extraction:skipping region: num_pix=351,shape:(15, 24, 3),area:351.0, as num_pix is < 7000
#  16% (30 of 179) |###                    | Elapsed Time: 0:00:26 ETA:   0:02:09INFO:object_extraction:Shapes of extracted regions: [(12, 41, 3), (195, 247, 3)]
# INFO:object_extraction:skipping region: num_pix=457,shape:(12, 41, 3),area:457.0, as num_pix is < 7000
#  17% (31 of 179) |###                    | Elapsed Time: 0:00:26 ETA:   0:02:08INFO:object_extraction:Shapes of extracted regions: [(33, 44, 3), (52, 285, 3)]
# INFO:object_extraction:skipping region: num_pix=1225,shape:(33, 44, 3),area:1225.0, as num_pix is < 7000
#  17% (32 of 179) |####                   | Elapsed Time: 0:00:27 ETA:   0:02:07INFO:object_extraction:Shapes of extracted regions: [(123, 372, 3)]
#  18% (33 of 179) |####                   | Elapsed Time: 0:00:28 ETA:   0:02:06INFO:object_extraction:Shapes of extracted regions: [(27, 142, 3), (40, 262, 3), (22, 30, 3)]
# INFO:object_extraction:skipping region: num_pix=2747,shape:(27, 142, 3),area:2747.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=638,shape:(22, 30, 3),area:638.0, as num_pix is < 7000
#  18% (34 of 179) |####                   | Elapsed Time: 0:00:29 ETA:   0:02:05INFO:object_extraction:Shapes of extracted regions: [(19, 38, 3), (77, 318, 3)]
# INFO:object_extraction:skipping region: num_pix=579,shape:(19, 38, 3),area:579.0, as num_pix is < 7000
#  19% (35 of 179) |####                   | Elapsed Time: 0:00:30 ETA:   0:02:04INFO:object_extraction:Shapes of extracted regions: [(217, 181, 3)]
#  20% (36 of 179) |####                   | Elapsed Time: 0:00:31 ETA:   0:02:04INFO:object_extraction:Shapes of extracted regions: [(217, 133, 3)]
#  20% (37 of 179) |####                   | Elapsed Time: 0:00:32 ETA:   0:02:03INFO:object_extraction:Shapes of extracted regions: [(10, 13, 3), (109, 303, 3)]
# INFO:object_extraction:skipping region: num_pix=130,shape:(10, 13, 3),area:130.0, as num_pix is < 7000
#  21% (38 of 179) |####                   | Elapsed Time: 0:00:32 ETA:   0:02:02INFO:object_extraction:Shapes of extracted regions: [(24, 21, 3), (49, 284, 3), (22, 24, 3)]
# INFO:object_extraction:skipping region: num_pix=500,shape:(24, 21, 3),area:500.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=522,shape:(22, 24, 3),area:522.0, as num_pix is < 7000
#  21% (39 of 179) |#####                  | Elapsed Time: 0:00:33 ETA:   0:02:01INFO:object_extraction:Shapes of extracted regions: [(111, 384, 3)]
#  22% (40 of 179) |#####                  | Elapsed Time: 0:00:34 ETA:   0:02:00INFO:object_extraction:Shapes of extracted regions: [(164, 197, 3)]
#  22% (41 of 179) |#####                  | Elapsed Time: 0:00:35 ETA:   0:01:59INFO:object_extraction:Shapes of extracted regions: [(54, 34, 3), (75, 28, 3), (62, 64, 3)]
# INFO:object_extraction:skipping region: num_pix=1631,shape:(54, 34, 3),area:1631.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=1832,shape:(75, 28, 3),area:1832.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=3060,shape:(62, 64, 3),area:3060.0, as num_pix is < 7000
#  23% (42 of 179) |#####                  | Elapsed Time: 0:00:36 ETA:   0:01:58INFO:object_extraction:Shapes of extracted regions: [(38, 181, 3), (59, 110, 3)]
# INFO:object_extraction:skipping region: num_pix=5261,shape:(38, 181, 3),area:5261.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=4815,shape:(59, 110, 3),area:4815.0, as num_pix is < 7000
#  24% (43 of 179) |#####                  | Elapsed Time: 0:00:37 ETA:   0:01:57INFO:object_extraction:Shapes of extracted regions: [(75, 312, 3)]
#  24% (44 of 179) |#####                  | Elapsed Time: 0:00:38 ETA:   0:01:57INFO:object_extraction:Shapes of extracted regions: [(71, 315, 3)]
#  25% (45 of 179) |#####                  | Elapsed Time: 0:00:39 ETA:   0:01:56INFO:object_extraction:Shapes of extracted regions: [(140, 358, 3)]
#  25% (46 of 179) |#####                  | Elapsed Time: 0:00:39 ETA:   0:01:55INFO:object_extraction:Shapes of extracted regions: [(87, 298, 3)]
#  26% (47 of 179) |######                 | Elapsed Time: 0:00:40 ETA:   0:01:54INFO:object_extraction:Shapes of extracted regions: [(138, 175, 3)]
#  26% (48 of 179) |######                 | Elapsed Time: 0:00:41 ETA:   0:01:53INFO:object_extraction:Shapes of extracted regions: [(54, 31, 3), (140, 79, 3)]
# INFO:object_extraction:skipping region: num_pix=1271,shape:(54, 31, 3),area:1271.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=6521,shape:(140, 79, 3),area:6521.0, as num_pix is < 7000
#  27% (49 of 179) |######                 | Elapsed Time: 0:00:42 ETA:   0:01:52INFO:object_extraction:Shapes of extracted regions: [(68, 331, 3)]
#  27% (50 of 179) |######                 | Elapsed Time: 0:00:43 ETA:   0:01:51INFO:object_extraction:Shapes of extracted regions: [(130, 299, 3)]
#  28% (51 of 179) |######                 | Elapsed Time: 0:00:44 ETA:   0:01:50INFO:object_extraction:Shapes of extracted regions: [(64, 97, 3), (116, 178, 3)]
# INFO:object_extraction:skipping region: num_pix=3131,shape:(64, 97, 3),area:3131.0, as num_pix is < 7000
#  29% (52 of 179) |######                 | Elapsed Time: 0:00:44 ETA:   0:01:49INFO:object_extraction:Shapes of extracted regions: [(64, 291, 3), (14, 21, 3)]
# INFO:object_extraction:skipping region: num_pix=277,shape:(14, 21, 3),area:277.0, as num_pix is < 7000
#  29% (53 of 179) |######                 | Elapsed Time: 0:00:45 ETA:   0:01:48INFO:object_extraction:Shapes of extracted regions: [(51, 311, 3)]
#  30% (54 of 179) |######                 | Elapsed Time: 0:00:46 ETA:   0:01:48INFO:object_extraction:Shapes of extracted regions: [(175, 307, 3)]
#  30% (55 of 179) |#######                | Elapsed Time: 0:00:47 ETA:   0:01:47INFO:object_extraction:Shapes of extracted regions: [(148, 336, 3)]
#  31% (56 of 179) |#######                | Elapsed Time: 0:00:48 ETA:   0:01:46INFO:object_extraction:Shapes of extracted regions: [(68, 311, 3)]
#  31% (57 of 179) |#######                | Elapsed Time: 0:00:49 ETA:   0:01:45INFO:object_extraction:Shapes of extracted regions: [(14, 35, 3), (143, 174, 3)]
# INFO:object_extraction:skipping region: num_pix=451,shape:(14, 35, 3),area:451.0, as num_pix is < 7000
#  32% (58 of 179) |#######                | Elapsed Time: 0:00:50 ETA:   0:01:44INFO:object_extraction:Shapes of extracted regions: [(19, 90, 3), (177, 69, 3)]
# INFO:object_extraction:skipping region: num_pix=1453,shape:(19, 90, 3),area:1453.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=6888,shape:(177, 69, 3),area:6888.0, as num_pix is < 7000
#  32% (59 of 179) |#######                | Elapsed Time: 0:00:51 ETA:   0:01:43INFO:object_extraction:Shapes of extracted regions: [(14, 63, 3), (67, 257, 3)]
# INFO:object_extraction:skipping region: num_pix=776,shape:(14, 63, 3),area:776.0, as num_pix is < 7000
#  33% (60 of 179) |#######                | Elapsed Time: 0:00:51 ETA:   0:01:42INFO:object_extraction:Shapes of extracted regions: [(210, 282, 3)]
#  34% (61 of 179) |#######                | Elapsed Time: 0:00:52 ETA:   0:01:42INFO:object_extraction:Shapes of extracted regions: [(100, 340, 3)]
#  34% (62 of 179) |#######                | Elapsed Time: 0:00:53 ETA:   0:01:41INFO:object_extraction:Shapes of extracted regions: [(152, 342, 3)]
#  35% (63 of 179) |########               | Elapsed Time: 0:00:54 ETA:   0:01:40INFO:object_extraction:Shapes of extracted regions: [(64, 329, 3)]
#  35% (64 of 179) |########               | Elapsed Time: 0:00:55 ETA:   0:01:39INFO:object_extraction:Shapes of extracted regions: [(27, 23, 3), (115, 235, 3)]
# INFO:object_extraction:skipping region: num_pix=594,shape:(27, 23, 3),area:594.0, as num_pix is < 7000
#  36% (65 of 179) |########               | Elapsed Time: 0:00:56 ETA:   0:01:38INFO:object_extraction:Shapes of extracted regions: [(157, 310, 3)]
#  36% (66 of 179) |########               | Elapsed Time: 0:00:57 ETA:   0:01:37INFO:object_extraction:Shapes of extracted regions: [(90, 326, 3)]
#  37% (67 of 179) |########               | Elapsed Time: 0:00:58 ETA:   0:01:36INFO:object_extraction:Shapes of extracted regions: [(202, 324, 3)]
#  37% (68 of 179) |########               | Elapsed Time: 0:00:58 ETA:   0:01:36INFO:object_extraction:Shapes of extracted regions: [(20, 117, 3), (59, 235, 3)]
# INFO:object_extraction:skipping region: num_pix=1971,shape:(20, 117, 3),area:1971.0, as num_pix is < 7000
#  38% (69 of 179) |########               | Elapsed Time: 0:00:59 ETA:   0:01:35INFO:object_extraction:Shapes of extracted regions: [(109, 214, 3)]
#  39% (70 of 179) |########               | Elapsed Time: 0:01:00 ETA:   0:01:34INFO:object_extraction:Shapes of extracted regions: [(35, 132, 3), (53, 230, 3)]
# INFO:object_extraction:skipping region: num_pix=3774,shape:(35, 132, 3),area:3774.0, as num_pix is < 7000
#  39% (71 of 179) |#########              | Elapsed Time: 0:01:01 ETA:   0:01:33INFO:object_extraction:Shapes of extracted regions: [(25, 74, 3), (56, 255, 3)]
# INFO:object_extraction:skipping region: num_pix=1515,shape:(25, 74, 3),area:1515.0, as num_pix is < 7000
#  40% (72 of 179) |#########              | Elapsed Time: 0:01:02 ETA:   0:01:32INFO:object_extraction:Shapes of extracted regions: [(143, 218, 3)]
#  40% (73 of 179) |#########              | Elapsed Time: 0:01:03 ETA:   0:01:31INFO:object_extraction:Shapes of extracted regions: [(131, 326, 3)]
#  41% (74 of 179) |#########              | Elapsed Time: 0:01:04 ETA:   0:01:30INFO:object_extraction:Shapes of extracted regions: [(103, 332, 3)]
#  41% (75 of 179) |#########              | Elapsed Time: 0:01:04 ETA:   0:01:30INFO:object_extraction:Shapes of extracted regions: [(35, 53, 3), (135, 161, 3)]
# INFO:object_extraction:skipping region: num_pix=1584,shape:(35, 53, 3),area:1584.0, as num_pix is < 7000
#  42% (76 of 179) |#########              | Elapsed Time: 0:01:05 ETA:   0:01:29INFO:object_extraction:Shapes of extracted regions: [(125, 290, 3)]
#  43% (77 of 179) |#########              | Elapsed Time: 0:01:06 ETA:   0:01:28INFO:object_extraction:Shapes of extracted regions: [(12, 23, 3), (62, 102, 3), (31, 164, 3)]
# INFO:object_extraction:skipping region: num_pix=260,shape:(12, 23, 3),area:260.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=5301,shape:(62, 102, 3),area:5301.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=4386,shape:(31, 164, 3),area:4386.0, as num_pix is < 7000
#  43% (78 of 179) |##########             | Elapsed Time: 0:01:07 ETA:   0:01:27INFO:object_extraction:Shapes of extracted regions: [(225, 116, 3), (51, 222, 3)]
#  44% (79 of 179) |##########             | Elapsed Time: 0:01:08 ETA:   0:01:26INFO:object_extraction:Shapes of extracted regions: [(35, 129, 3), (51, 228, 3)]
# INFO:object_extraction:skipping region: num_pix=3620,shape:(35, 129, 3),area:3620.0, as num_pix is < 7000
#  44% (80 of 179) |##########             | Elapsed Time: 0:01:09 ETA:   0:01:25INFO:object_extraction:Shapes of extracted regions: [(23, 82, 3), (55, 247, 3)]
# INFO:object_extraction:skipping region: num_pix=1603,shape:(23, 82, 3),area:1603.0, as num_pix is < 7000
#  45% (81 of 179) |##########             | Elapsed Time: 0:01:10 ETA:   0:01:24INFO:object_extraction:Shapes of extracted regions: [(146, 164, 3)]
#  45% (82 of 179) |##########             | Elapsed Time: 0:01:11 ETA:   0:01:24INFO:object_extraction:Shapes of extracted regions: [(37, 145, 3), (39, 57, 3), (90, 153, 3)]
# INFO:object_extraction:skipping region: num_pix=4432,shape:(37, 145, 3),area:4432.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=1628,shape:(39, 57, 3),area:1628.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=5935,shape:(90, 153, 3),area:5935.0, as num_pix is < 7000
#  46% (83 of 179) |##########             | Elapsed Time: 0:01:11 ETA:   0:01:23INFO:object_extraction:Shapes of extracted regions: [(146, 296, 3)]
#  46% (84 of 179) |##########             | Elapsed Time: 0:01:12 ETA:   0:01:22INFO:object_extraction:Shapes of extracted regions: [(73, 342, 3)]
#  47% (85 of 179) |##########             | Elapsed Time: 0:01:13 ETA:   0:01:21INFO:object_extraction:Shapes of extracted regions: [(30, 24, 3), (123, 261, 3)]
# INFO:object_extraction:skipping region: num_pix=679,shape:(30, 24, 3),area:679.0, as num_pix is < 7000
#  48% (86 of 179) |###########            | Elapsed Time: 0:01:14 ETA:   0:01:20INFO:object_extraction:Shapes of extracted regions: [(133, 183, 3)]
# INFO:object_extraction:skipping region: num_pix=6272,shape:(133, 183, 3),area:6272.0, as num_pix is < 7000
#  48% (87 of 179) |###########            | Elapsed Time: 0:01:15 ETA:   0:01:19INFO:object_extraction:Shapes of extracted regions: [(139, 187, 3)]
# INFO:object_extraction:skipping region: num_pix=6513,shape:(139, 187, 3),area:6513.0, as num_pix is < 7000
#  49% (88 of 179) |###########            | Elapsed Time: 0:01:16 ETA:   0:01:18INFO:object_extraction:Shapes of extracted regions: [(29, 23, 3), (127, 237, 3)]
# INFO:object_extraction:skipping region: num_pix=642,shape:(29, 23, 3),area:642.0, as num_pix is < 7000
#  49% (89 of 179) |###########            | Elapsed Time: 0:01:17 ETA:   0:01:18INFO:object_extraction:Shapes of extracted regions: [(72, 352, 3)]
#  50% (90 of 179) |###########            | Elapsed Time: 0:01:18 ETA:   0:01:17INFO:object_extraction:Shapes of extracted regions: [(167, 329, 3)]
#  50% (91 of 179) |###########            | Elapsed Time: 0:01:18 ETA:   0:01:16INFO:object_extraction:Shapes of extracted regions: [(16, 53, 3), (63, 152, 3)]
# INFO:object_extraction:skipping region: num_pix=774,shape:(16, 53, 3),area:774.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=6362,shape:(63, 152, 3),area:6362.0, as num_pix is < 7000
#  51% (92 of 179) |###########            | Elapsed Time: 0:01:19 ETA:   0:01:15INFO:object_extraction:Shapes of extracted regions: [(87, 97, 3), (38, 43, 3)]
# INFO:object_extraction:skipping region: num_pix=5870,shape:(87, 97, 3),area:5870.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=1328,shape:(38, 43, 3),area:1328.0, as num_pix is < 7000
#  51% (93 of 179) |###########            | Elapsed Time: 0:01:20 ETA:   0:01:14INFO:object_extraction:Shapes of extracted regions: [(38, 106, 3), (18, 25, 3), (43, 192, 3), (25, 260, 3), (19, 12, 3)]
# INFO:object_extraction:skipping region: num_pix=3102,shape:(38, 106, 3),area:3102.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=396,shape:(18, 25, 3),area:396.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=5497,shape:(43, 192, 3),area:5497.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=4883,shape:(25, 260, 3),area:4883.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=216,shape:(19, 12, 3),area:216.0, as num_pix is < 7000
#  52% (94 of 179) |############           | Elapsed Time: 0:01:21 ETA:   0:01:13INFO:object_extraction:Shapes of extracted regions: [(63, 97, 3), (53, 149, 3)]
# INFO:object_extraction:skipping region: num_pix=5079,shape:(63, 97, 3),area:5079.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=4169,shape:(53, 149, 3),area:4169.0, as num_pix is < 7000
#  53% (95 of 179) |############           | Elapsed Time: 0:01:22 ETA:   0:01:12INFO:object_extraction:Shapes of extracted regions: [(132, 230, 3)]
#  53% (96 of 179) |############           | Elapsed Time: 0:01:23 ETA:   0:01:11INFO:object_extraction:Shapes of extracted regions: [(70, 327, 3)]
#  54% (97 of 179) |############           | Elapsed Time: 0:01:24 ETA:   0:01:11INFO:object_extraction:Shapes of extracted regions: [(153, 275, 3)]
#  54% (98 of 179) |############           | Elapsed Time: 0:01:24 ETA:   0:01:10INFO:object_extraction:Shapes of extracted regions: [(149, 273, 3), (11, 13, 3)]
# INFO:object_extraction:skipping region: num_pix=143,shape:(11, 13, 3),area:143.0, as num_pix is < 7000
#  55% (99 of 179) |############           | Elapsed Time: 0:01:25 ETA:   0:01:09INFO:object_extraction:Shapes of extracted regions: [(115, 204, 3)]
# INFO:object_extraction:skipping region: num_pix=6288,shape:(115, 204, 3),area:6288.0, as num_pix is < 7000
#  55% (100 of 179) |############          | Elapsed Time: 0:01:26 ETA:   0:01:08INFO:object_extraction:Shapes of extracted regions: [(45, 30, 3), (136, 305, 3)]
# INFO:object_extraction:skipping region: num_pix=935,shape:(45, 30, 3),area:935.0, as num_pix is < 7000
#  56% (101 of 179) |############          | Elapsed Time: 0:01:27 ETA:   0:01:07INFO:object_extraction:Shapes of extracted regions: [(27, 24, 3), (117, 303, 3)]
# INFO:object_extraction:skipping region: num_pix=626,shape:(27, 24, 3),area:626.0, as num_pix is < 7000
#  56% (102 of 179) |############          | Elapsed Time: 0:01:28 ETA:   0:01:06INFO:object_extraction:Shapes of extracted regions: [(79, 332, 3)]
#  57% (103 of 179) |############          | Elapsed Time: 0:01:29 ETA:   0:01:05INFO:object_extraction:Shapes of extracted regions: [(41, 51, 3), (115, 196, 3), (15, 34, 3)]
# INFO:object_extraction:skipping region: num_pix=1701,shape:(41, 51, 3),area:1701.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=454,shape:(15, 34, 3),area:454.0, as num_pix is < 7000
#  58% (104 of 179) |############          | Elapsed Time: 0:01:30 ETA:   0:01:05INFO:object_extraction:Shapes of extracted regions: [(174, 348, 3)]
#  58% (105 of 179) |############          | Elapsed Time: 0:01:31 ETA:   0:01:04INFO:object_extraction:Shapes of extracted regions: [(74, 346, 3)]
#  59% (106 of 179) |#############         | Elapsed Time: 0:01:31 ETA:   0:01:03INFO:object_extraction:Shapes of extracted regions: [(71, 255, 3)]
#  59% (107 of 179) |#############         | Elapsed Time: 0:01:32 ETA:   0:01:02INFO:object_extraction:Shapes of extracted regions: [(176, 188, 3)]
#  60% (108 of 179) |#############         | Elapsed Time: 0:01:33 ETA:   0:01:01INFO:object_extraction:Shapes of extracted regions: [(165, 131, 3)]
#  60% (109 of 179) |#############         | Elapsed Time: 0:01:34 ETA:   0:01:00INFO:object_extraction:Shapes of extracted regions: [(60, 289, 3)]
#  61% (110 of 179) |#############         | Elapsed Time: 0:01:35 ETA:   0:00:59INFO:object_extraction:Shapes of extracted regions: [(68, 293, 3), (20, 12, 3)]
# INFO:object_extraction:skipping region: num_pix=228,shape:(20, 12, 3),area:228.0, as num_pix is < 7000
#  62% (111 of 179) |#############         | Elapsed Time: 0:01:36 ETA:   0:00:58INFO:object_extraction:Shapes of extracted regions: [(156, 356, 3)]
#  62% (112 of 179) |#############         | Elapsed Time: 0:01:37 ETA:   0:00:58INFO:object_extraction:Shapes of extracted regions: [(110, 193, 3)]
# INFO:object_extraction:skipping region: num_pix=6329,shape:(110, 193, 3),area:6329.0, as num_pix is < 7000
#  63% (113 of 179) |#############         | Elapsed Time: 0:01:37 ETA:   0:00:57INFO:object_extraction:Shapes of extracted regions: [(104, 221, 3)]
# INFO:object_extraction:skipping region: num_pix=6865,shape:(104, 221, 3),area:6865.0, as num_pix is < 7000
#  63% (114 of 179) |##############        | Elapsed Time: 0:01:38 ETA:   0:00:56INFO:object_extraction:Shapes of extracted regions: [(158, 353, 3)]
#  64% (115 of 179) |##############        | Elapsed Time: 0:01:39 ETA:   0:00:55INFO:object_extraction:Shapes of extracted regions: [(91, 357, 3)]
#  64% (116 of 179) |##############        | Elapsed Time: 0:01:40 ETA:   0:00:54INFO:object_extraction:Shapes of extracted regions: [(83, 333, 3)]
#  65% (117 of 179) |##############        | Elapsed Time: 0:01:41 ETA:   0:00:53INFO:object_extraction:Shapes of extracted regions: [(20, 141, 3), (147, 179, 3)]
# INFO:object_extraction:skipping region: num_pix=2309,shape:(20, 141, 3),area:2309.0, as num_pix is < 7000
#  65% (118 of 179) |##############        | Elapsed Time: 0:01:42 ETA:   0:00:52INFO:object_extraction:Shapes of extracted regions: [(12, 34, 3), (162, 162, 3)]
# INFO:object_extraction:skipping region: num_pix=397,shape:(12, 34, 3),area:397.0, as num_pix is < 7000
#  66% (119 of 179) |##############        | Elapsed Time: 0:01:43 ETA:   0:00:52INFO:object_extraction:Shapes of extracted regions: [(26, 146, 3), (12, 30, 3), (21, 21, 3), (41, 73, 3)]
# INFO:object_extraction:skipping region: num_pix=3421,shape:(26, 146, 3),area:3421.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=345,shape:(12, 30, 3),area:345.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=439,shape:(21, 21, 3),area:439.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=2326,shape:(41, 73, 3),area:2326.0, as num_pix is < 7000
#  67% (120 of 179) |##############        | Elapsed Time: 0:01:44 ETA:   0:00:51INFO:object_extraction:Shapes of extracted regions: [(24, 61, 3), (18, 43, 3), (148, 165, 3), (21, 19, 3)]
# INFO:object_extraction:skipping region: num_pix=1156,shape:(24, 61, 3),area:1156.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=565,shape:(18, 43, 3),area:565.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=353,shape:(21, 19, 3),area:353.0, as num_pix is < 7000
#  67% (121 of 179) |##############        | Elapsed Time: 0:01:44 ETA:   0:00:50INFO:object_extraction:Shapes of extracted regions: [(141, 215, 3)]
#  68% (122 of 179) |##############        | Elapsed Time: 0:01:45 ETA:   0:00:49INFO:object_extraction:Shapes of extracted regions: [(159, 304, 3)]
#  68% (123 of 179) |###############       | Elapsed Time: 0:01:46 ETA:   0:00:48INFO:object_extraction:Shapes of extracted regions: [(191, 332, 3)]
#  69% (124 of 179) |###############       | Elapsed Time: 0:01:47 ETA:   0:00:47INFO:object_extraction:Shapes of extracted regions: [(173, 286, 3)]
#  69% (125 of 179) |###############       | Elapsed Time: 0:01:48 ETA:   0:00:46INFO:object_extraction:Shapes of extracted regions: [(20, 20, 3), (90, 293, 3)]
# INFO:object_extraction:skipping region: num_pix=400,shape:(20, 20, 3),area:400.0, as num_pix is < 7000
#  70% (126 of 179) |###############       | Elapsed Time: 0:01:49 ETA:   0:00:45INFO:object_extraction:Shapes of extracted regions: [(67, 280, 3), (16, 26, 3)]
# INFO:object_extraction:skipping region: num_pix=368,shape:(16, 26, 3),area:368.0, as num_pix is < 7000
#  70% (127 of 179) |###############       | Elapsed Time: 0:01:50 ETA:   0:00:45INFO:object_extraction:Shapes of extracted regions: [(101, 274, 3)]
#  71% (128 of 179) |###############       | Elapsed Time: 0:01:50 ETA:   0:00:44INFO:object_extraction:Shapes of extracted regions: [(85, 304, 3)]
#  72% (129 of 179) |###############       | Elapsed Time: 0:01:51 ETA:   0:00:43INFO:object_extraction:Shapes of extracted regions: [(186, 306, 3)]
#  72% (130 of 179) |###############       | Elapsed Time: 0:01:52 ETA:   0:00:42INFO:object_extraction:Shapes of extracted regions: [(177, 336, 3)]
#  73% (131 of 179) |################      | Elapsed Time: 0:01:53 ETA:   0:00:41INFO:object_extraction:Shapes of extracted regions: [(54, 63, 3), (104, 250, 3)]
# INFO:object_extraction:skipping region: num_pix=2661,shape:(54, 63, 3),area:2661.0, as num_pix is < 7000
#  73% (132 of 179) |################      | Elapsed Time: 0:01:54 ETA:   0:00:40INFO:object_extraction:Shapes of extracted regions: [(137, 221, 3)]
#  74% (133 of 179) |################      | Elapsed Time: 0:01:55 ETA:   0:00:39INFO:object_extraction:Shapes of extracted regions: [(132, 268, 3)]
#  74% (134 of 179) |################      | Elapsed Time: 0:01:56 ETA:   0:00:39INFO:object_extraction:Shapes of extracted regions: [(20, 85, 3), (52, 80, 3), (60, 126, 3)]
# INFO:object_extraction:skipping region: num_pix=1357,shape:(20, 85, 3),area:1357.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=3570,shape:(52, 80, 3),area:3570.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=3478,shape:(60, 126, 3),area:3478.0, as num_pix is < 7000
#  75% (135 of 179) |################      | Elapsed Time: 0:01:57 ETA:   0:00:38INFO:object_extraction:Shapes of extracted regions: [(59, 383, 3)]
#  75% (136 of 179) |################      | Elapsed Time: 0:01:57 ETA:   0:00:37INFO:object_extraction:Shapes of extracted regions: [(212, 284, 3)]
#  76% (137 of 179) |################      | Elapsed Time: 0:01:58 ETA:   0:00:36INFO:object_extraction:Shapes of extracted regions: [(27, 17, 3), (20, 35, 3), (119, 179, 3), (76, 105, 3)]
# INFO:object_extraction:skipping region: num_pix=440,shape:(27, 17, 3),area:440.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=566,shape:(20, 35, 3),area:566.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=6251,shape:(76, 105, 3),area:6251.0, as num_pix is < 7000
#  77% (138 of 179) |################      | Elapsed Time: 0:01:59 ETA:   0:00:35INFO:object_extraction:Shapes of extracted regions: [(63, 306, 3), (30, 44, 3)]
# INFO:object_extraction:skipping region: num_pix=1156,shape:(30, 44, 3),area:1156.0, as num_pix is < 7000
#  77% (139 of 179) |#################     | Elapsed Time: 0:02:00 ETA:   0:00:34INFO:object_extraction:Shapes of extracted regions: [(146, 289, 3)]
#  78% (140 of 179) |#################     | Elapsed Time: 0:02:01 ETA:   0:00:33INFO:object_extraction:Shapes of extracted regions: [(103, 290, 3)]
#  78% (141 of 179) |#################     | Elapsed Time: 0:02:02 ETA:   0:00:32INFO:object_extraction:Shapes of extracted regions: [(116, 294, 3)]
#  79% (142 of 179) |#################     | Elapsed Time: 0:02:03 ETA:   0:00:32INFO:object_extraction:Shapes of extracted regions: [(132, 294, 3)]
#  79% (143 of 179) |#################     | Elapsed Time: 0:02:04 ETA:   0:00:31INFO:object_extraction:Shapes of extracted regions: [(43, 292, 3), (24, 35, 3)]
# INFO:object_extraction:skipping region: num_pix=786,shape:(24, 35, 3),area:786.0, as num_pix is < 7000
#  80% (144 of 179) |#################     | Elapsed Time: 0:02:04 ETA:   0:00:30INFO:object_extraction:Shapes of extracted regions: [(30, 125, 3), (78, 198, 3), (74, 131, 3), (34, 19, 3)]
# INFO:object_extraction:skipping region: num_pix=2507,shape:(30, 125, 3),area:2507.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=6930,shape:(78, 198, 3),area:6930.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=548,shape:(34, 19, 3),area:548.0, as num_pix is < 7000
#  81% (145 of 179) |#################     | Elapsed Time: 0:02:05 ETA:   0:00:29INFO:object_extraction:Shapes of extracted regions: [(188, 303, 3)]
#  81% (146 of 179) |#################     | Elapsed Time: 0:02:06 ETA:   0:00:28INFO:object_extraction:Shapes of extracted regions: [(64, 381, 3)]
#  82% (147 of 179) |##################    | Elapsed Time: 0:02:07 ETA:   0:00:27INFO:object_extraction:Shapes of extracted regions: [(20, 20, 3), (57, 329, 3)]
# INFO:object_extraction:skipping region: num_pix=400,shape:(20, 20, 3),area:400.0, as num_pix is < 7000
#  82% (148 of 179) |##################    | Elapsed Time: 0:02:08 ETA:   0:00:26INFO:object_extraction:Shapes of extracted regions: [(10, 27, 3), (69, 360, 3)]
# INFO:object_extraction:skipping region: num_pix=270,shape:(10, 27, 3),area:270.0, as num_pix is < 7000
#  83% (149 of 179) |##################    | Elapsed Time: 0:02:09 ETA:   0:00:26INFO:object_extraction:Shapes of extracted regions: [(62, 96, 3), (68, 139, 3)]
# INFO:object_extraction:skipping region: num_pix=4849,shape:(62, 96, 3),area:4849.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=4103,shape:(68, 139, 3),area:4103.0, as num_pix is < 7000
#  83% (150 of 179) |##################    | Elapsed Time: 0:02:10 ETA:   0:00:25INFO:object_extraction:Shapes of extracted regions: [(135, 258, 3)]
#  84% (151 of 179) |##################    | Elapsed Time: 0:02:11 ETA:   0:00:24INFO:object_extraction:Shapes of extracted regions: [(116, 270, 3)]
#  84% (152 of 179) |##################    | Elapsed Time: 0:02:11 ETA:   0:00:23INFO:object_extraction:Shapes of extracted regions: [(117, 283, 3)]
#  85% (153 of 179) |##################    | Elapsed Time: 0:02:12 ETA:   0:00:22INFO:object_extraction:Shapes of extracted regions: [(126, 261, 3)]
#  86% (154 of 179) |##################    | Elapsed Time: 0:02:13 ETA:   0:00:21INFO:object_extraction:Shapes of extracted regions: [(162, 289, 3)]
#  86% (155 of 179) |###################   | Elapsed Time: 0:02:14 ETA:   0:00:20INFO:object_extraction:Shapes of extracted regions: [(109, 400, 3)]
#  87% (156 of 179) |###################   | Elapsed Time: 0:02:15 ETA:   0:00:19INFO:object_extraction:Shapes of extracted regions: [(184, 244, 3)]
#  87% (157 of 179) |###################   | Elapsed Time: 0:02:16 ETA:   0:00:19INFO:object_extraction:Shapes of extracted regions: [(20, 39, 3), (125, 158, 3), (94, 116, 3)]
# INFO:object_extraction:skipping region: num_pix=650,shape:(20, 39, 3),area:650.0, as num_pix is < 7000
#  88% (158 of 179) |###################   | Elapsed Time: 0:02:16 ETA:   0:00:18INFO:object_extraction:Shapes of extracted regions: [(185, 276, 3)]
#  88% (159 of 179) |###################   | Elapsed Time: 0:02:17 ETA:   0:00:17INFO:object_extraction:Shapes of extracted regions: [(88, 339, 3)]
#  89% (160 of 179) |###################   | Elapsed Time: 0:02:18 ETA:   0:00:16INFO:object_extraction:Shapes of extracted regions: [(90, 236, 3)]
#  89% (161 of 179) |###################   | Elapsed Time: 0:02:19 ETA:   0:00:15INFO:object_extraction:Shapes of extracted regions: [(167, 264, 3)]
#  90% (162 of 179) |###################   | Elapsed Time: 0:02:20 ETA:   0:00:14INFO:object_extraction:Shapes of extracted regions: [(142, 347, 3), (20, 20, 3)]
# INFO:object_extraction:skipping region: num_pix=400,shape:(20, 20, 3),area:400.0, as num_pix is < 7000
#  91% (163 of 179) |####################  | Elapsed Time: 0:02:21 ETA:   0:00:13INFO:object_extraction:Shapes of extracted regions: [(194, 227, 3)]
#  91% (164 of 179) |####################  | Elapsed Time: 0:02:22 ETA:   0:00:13INFO:object_extraction:Shapes of extracted regions: [(154, 288, 3)]
#  92% (165 of 179) |####################  | Elapsed Time: 0:02:23 ETA:   0:00:12INFO:object_extraction:Shapes of extracted regions: [(83, 240, 3)]
#  92% (166 of 179) |####################  | Elapsed Time: 0:02:23 ETA:   0:00:11INFO:object_extraction:Shapes of extracted regions: [(107, 324, 3)]
#  93% (167 of 179) |####################  | Elapsed Time: 0:02:24 ETA:   0:00:10INFO:object_extraction:Shapes of extracted regions: [(220, 314, 3)]
#  93% (168 of 179) |####################  | Elapsed Time: 0:02:25 ETA:   0:00:09INFO:object_extraction:Shapes of extracted regions: [(30, 21, 3), (210, 215, 3)]
# INFO:object_extraction:skipping region: num_pix=554,shape:(30, 21, 3),area:554.0, as num_pix is < 7000
#  94% (169 of 179) |####################  | Elapsed Time: 0:02:26 ETA:   0:00:08INFO:object_extraction:Shapes of extracted regions: [(75, 235, 3), (42, 59, 3), (70, 64, 3), (26, 83, 3)]
# INFO:object_extraction:skipping region: num_pix=1896,shape:(42, 59, 3),area:1896.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=3950,shape:(70, 64, 3),area:3950.0, as num_pix is < 7000
# INFO:object_extraction:skipping region: num_pix=1822,shape:(26, 83, 3),area:1822.0, as num_pix is < 7000
#  94% (170 of 179) |####################  | Elapsed Time: 0:02:27 ETA:   0:00:07INFO:object_extraction:Shapes of extracted regions: [(146, 341, 3)]
#  95% (171 of 179) |##################### | Elapsed Time: 0:02:28 ETA:   0:00:06INFO:object_extraction:Shapes of extracted regions: [(164, 346, 3)]
#  96% (172 of 179) |##################### | Elapsed Time: 0:02:29 ETA:   0:00:06INFO:object_extraction:Shapes of extracted regions: [(209, 246, 3)]
#  96% (173 of 179) |##################### | Elapsed Time: 0:02:30 ETA:   0:00:05INFO:object_extraction:Shapes of extracted regions: [(27, 49, 3), (176, 238, 3)]
# INFO:object_extraction:skipping region: num_pix=980,shape:(27, 49, 3),area:980.0, as num_pix is < 7000
#  97% (174 of 179) |##################### | Elapsed Time: 0:02:31 ETA:   0:00:04INFO:object_extraction:Shapes of extracted regions: [(102, 235, 3)]
#  97% (175 of 179) |##################### | Elapsed Time: 0:02:31 ETA:   0:00:03INFO:object_extraction:Shapes of extracted regions: [(119, 247, 3)]
#  98% (176 of 179) |##################### | Elapsed Time: 0:02:32 ETA:   0:00:02INFO:object_extraction:Shapes of extracted regions: [(86, 264, 3)]
#  98% (177 of 179) |##################### | Elapsed Time: 0:02:33 ETA:   0:00:01INFO:object_extraction:Shapes of extracted regions: [(200, 286, 3)]
#  99% (178 of 179) |##################### | Elapsed Time: 0:02:34 ETA:   0:00:00INFO:object_extraction:Shapes of extracted regions: [(198, 265, 3)]
# 100% (179 of 179) |######################| Elapsed Time: 0:02:35 Time:  0:02:35
# INFO:object_extraction:Die Bildausschnitte wurden hierher kopiert: output/geschirr/1_object_extraction_output/Ausschnitte

# %% [markdown]
# Alternativ kann die Ausgabe der folgenden Zelle genutzt werden, um in der Kommandozeile das Skript [object_extraction.py](https://gitlab.ost.ch/beat.toedtli/learning-city-lab/-/blob/main/1_object_extraction/object_extraction.py?ref_type=heads)[im Verzeichnis [1_object_extraction](https://gitlab.ost.ch/beat.toedtli/learning-city-lab/-/tree/main/1_object_extraction?ref_type=heads) auszuführen.

# %%
from pathlib import Path
cmd = f"python3 '{pfad_zu_object_extraction}/object_extraction.py' \
-y -o '{Ausgabepfad}' -pr {pr[0]},{pr[1]} -fr {fr} -fc {fc} -es {es} -ds {ds} \
-vth {vth} -mpx {mpx} f'{pfad_zu_daten_string}/*.{Bilddateiendung}'"
print("Der Kommandozeilenbefehl lautet:\n",cmd)
# Out:
# Der Kommandozeilenbefehl lautet:
#  python3 './object_extraction.py' -y -o 'output/geschirr/1_object_extraction_output' -pr 225,400 -fr 0.0 -fc 0.0 -es 8 -ds 20 -vth -140 -mpx 7000 f'data/input/geschirr/*.jpg'

# %%
#Die Ausschnitte sind nun hier:
print(Ausgabepfad/'Ausschnitte')
# hier einige Beispiele:
# !ls {'"'+str(Ausgabepfad/'Ausschnitte')+'"'}|head -n 5
# Out:
# output/geschirr/1_object_extraction_output/Ausschnitte
# gabel-01_0_9638.jpg
# gabel-01_0_9639.jpg
# gabel-01_0_9640.jpg
# gabel-01_0_9641.jpg
# gabel-01_0_9642.jpg

# %% [markdown]
# Wir können uns die Ausschnitte anschauen:

# %%
fn = Ausgabepfad/'Ausschnitte'/'loeffel-01_0_9507.jpg'
if fn.exists():
    im = plt.imread(fn)
    show_image(im);

# %% [markdown]
# Bevor wir die Bilder herunterladen, wollen wir sie in Unterordner pro Klasse anordnen.

# %% [markdown]
# # Bilden von Unterordner pro Klasse
# Keras, unsere Deep Learning Bibliothek, hat eine einfache Routine, um Kategorisierte Bilder zu laden: Dazu müssen alle Bilder einer Klasse in einem Unterordner liegen, welcher als Namen die Klassenbezeichnung trägt. Diese Zuordnung kann natürlich von Hand vorgenommen werden. Im Fall des Giraffendatensatzes ist das Klassenlabel aber bereits im Dateinamen der Bilder codiert.
#
# Um den Klassennamen 'rot' aus dem Dateinamen 'rot-17_0_10.jpg' zu extrahieren, sind reguläre Ausdrücke sehr nützlich. Reguläre Ausdrücke sind ziemlich kryptisch, aber mächtig und (nach etwas Übung) durchaus handlich.
# Wir importieren zunächst die Standard-[Python-Bibliothek](https://docs.python.org/3/library/re.html), welche reguläre Ausdrücke implementiert:

# %% [markdown]
# #### Reguläre Ausdrücke

# %%
import re
help(re.sub) #oder re.sub?
# Out:
# Help on function sub in module re:
#
# sub(pattern, repl, string, count=0, flags=0)
#     Return the string obtained by replacing the leftmost
#     non-overlapping occurrences of the pattern in string by the
#     replacement repl.  repl can be either a string or a callable;
#     if a string, backslash escapes in it are processed.  If it is
#     a callable, it's passed the Match object and must return
#     a replacement string to be used.

# %%
re.sub('^([^-]*-\d+).*$','\\1','messer-01_9568.jpg')
# Out:
# 'messer-01'

# %% [markdown]
# Der reguläre Ausdruck `^([^-]*)-.*$` hat's durchaus in sich, ist aber verständlicher, wenn man folgendes weiss:
# - `^` bezeichnet den Beginn einer Zeichenkette
# - `$` bezeichnet das Ende einer Zeichenkette
# - `.` bezeichnet ein beliebiges Zeichen
# - `*` meint "Null-mal, einmal oder beliebig oft". Gemeint ist hier das Zeichen davor ("."), als "kein oder beliebig viele beliebige Zeichen".
# - `( )` Die Klammern gehören zusammen und bilden eine Gruppe: alle Zeichen dazwischen werden in einer Variablen abgespeichert, welche "\1" heisst. Dies sind die einzigen Zeichen, welche nach der Substitution die verbleibende Zeichenkette ausmachen: Im zweiten Argument von `re.sub` steht, womit ein "gematchtes Muster" (engl. matched pattern) im String ersetzt wird.
# - In eckigen Klammern, `[]`, können Zeichen aufgezählt werden, die auftauchen dürfen. Innerhalb von eckigen Klammern bedeutet `^` *nicht* den Beginn des Strings, sondern eine Negation. Der Ausdruck `[^-]` bezeichnet daher ein beliebiges Zeichen, welches aber nicht das Minuszeichen sein darf.
#
# Insgesamt sagt der Ausdruck `'^([^-]*)-.*$'` also so etwas wie:
# *Eine Zeichenkette matcht, wenn sie mit einer beliebigen Folge von Zeichen beginnt, welche nicht das Zeichen "-" ist, gefolgt von einem Minuszeichen. Diese Zeichen vor dem Minus bilden die Gruppe 1. Nach dieser Gruppe muss also ein "-" folgen, und danach dürfen noch beliebig viele beliebige Zeichen folgen bis zum Ende der Zeichenkette. Ersetze diese ganze Zeichenkette (von Anfang bis Ende) mit der Gruppe.*
#
# In einfacherer Sprache ausgedrückt wird die Zeichenkette vor dem Minuszeichen extrahiert- sie enthält ja den Klassennamen.

# %% [markdown]
# #### Pandas DataFrames
# Pandas DataFrames sind sehr nützliche tabellenartige Strukturen. Sie eignen sich v.a. für die Datenanalyse und Visualisierung von strukturierten Daten. Im Folgenden werden diese genutzt, um das Klassenlabel zu bestimmen, welches für die Erstellung der Baumstruktur nützlich ist.

# %%
volle_Dateinamen = [full_file_name for full_file_name in (Ausgabepfad/'Ausschnitte').glob('*.'+Bilddateiendung)]
Basisnamen =  [full_file_name for full_file_name in (Ausgabepfad/'Ausschnitte').glob('*.'+Bilddateiendung)]

Klassenlabel = [re.sub('^([^-]*-\d+).*$','\\1',bn.name) for bn in Basisnamen] #Wende den regulären Ausdruck an
#Einfach nur, weil's cool ist: Pandas DataFrames! Hier eröffnet sich eine ganze Welt von Möglichkeiten
df = pd.DataFrame({'Dateiname':volle_Dateinamen,'Basisname':Basisnamen,'Klassenlabel':Klassenlabel})
df
# Out:
#                                              Dateiname  \
# 0    output/geschirr/1_object_extraction_output/Aus...
# 1    output/geschirr/1_object_extraction_output/Aus...
# 2    output/geschirr/1_object_extraction_output/Aus...
# 3    output/geschirr/1_object_extraction_output/Aus...
# 4    output/geschirr/1_object_extraction_output/Aus...
# ..                                                 ...
# 157  output/geschirr/1_object_extraction_output/Aus...
# 158  output/geschirr/1_object_extraction_output/Aus...
# 159  output/geschirr/1_object_extraction_output/Aus...
# 160  output/geschirr/1_object_extraction_output/Aus...
# 161  output/geschirr/1_object_extraction_output/Aus...
#
#                                              Basisname Klassenlabel
# 0    output/geschirr/1_object_extraction_output/Aus...     gabel-01
# 1    output/geschirr/1_object_extraction_output/Aus...     gabel-01
# 2    output/geschirr/1_object_extraction_output/Aus...     gabel-01
# 3    output/geschirr/1_object_extraction_output/Aus...    messer-01
# 4    output/geschirr/1_object_extraction_output/Aus...    messer-01
# ..                                                 ...          ...
# 157  output/geschirr/1_object_extraction_output/Aus...   loeffel-01
# 158  output/geschirr/1_object_extraction_output/Aus...   loeffel-01
# 159  output/geschirr/1_object_extraction_output/Aus...    messer-01
# 160  output/geschirr/1_object_extraction_output/Aus...    messer-01
# 161  output/geschirr/1_object_extraction_output/Aus...     gabel-01
#
# [162 rows x 3 columns]

# %% [markdown]
# #### Train-Test-Split
# An dieser Stelle lohnt es sich, kurz innezuhalten: Unsere grandiose Strategie ist es, aus Bildern Objekte zu extrahieren und auf diesen dann ein Modell zu trainieren. Aber wir können nicht alle Daten als Trainingsdaten verwenden, sonst haben wir nichts mehr, um die *Generalisierungsfähigkeit* unseres Modells zu messen!
# Die Realität ist, dass wir nur ungern später nochmals neue Daten aufnehmen wollen. Die Liste in `df` oben ist alles, was uns zur Verfügung steht. Es macht daher Sinn, bereits jetzt einen Teil dieser Daten zurückzulegen und zu *schwören* diese Daten nicht für das Training zu benutzen. Wir brauchen ca. 20% *frische* Daten, an denen wir die Verallgemeinerungsfähigkeit unseres Modells überprüfen können.
# [Scikit-Learn](https://scikit-learn.org) bietet uns [hier](https://scikit-learn.org/stable/auto_examples/model_selection/plot_cv_indices.html#sphx-glr-auto-examples-model-selection-plot-cv-indices-py) verschiedene Strategien an, wie wir aus unseren Trainingsdaten einen Testdatensatz absondern können. Wir könnten einfach [zufällig splitten](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html#sklearn.model_selection.ShuffleSplit). Das ist naiv. Lieber eine [k-fache Kreuzvalidierung](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html#sklearn.model_selection.KFold). Aber was, wenn zufälligerweise eine Klasse nur im Testdatensatz auftaucht, und gar nicht im Trainingsdatensatz?! Also [stratifizieren](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold) wir. Ok- und was ist, wenn wir überprüfen wollen, dass wir in Bezug auf eine bestimmte Untergruppierung (z.B. nach Geschlecht, Ethnie,...) gut von einer Gruppe auf eine andere verallgemeinern können müssen? Dann darf eine [Gruppe nur in einem Fold vorkommen](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedGroupKFold.html#sklearn.model_selection.StratifiedGroupKFold). Sie sehen- richtig zu splitten kann herausfordernd sein!
# Hier jedenfalls möchten wir zumindest stratifizieren. Wir nehmen mal [StratifiedKFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold), um unsere Daten zu splitten.

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
Xtrain,Xtest,ytrain,ytest = train_test_split(df[['Dateiname','Basisname']],df.Klassenlabel,test_size=0.2,train_size=0.8,stratify =df.Klassenlabel,random_state=42)
# Das Fixieren des random_state bedeutet, dass immer der gleiche Split gemacht wird. Dadurch wird verhindert, dass durch mehrfaches durchlaufen immer mal wieder andere Daten für das Training
# benutzt werden. Denn dadurch würde man sich letztlich beim Training alle Daten anschauen, auch die Testdaten. Subtiler Punkt- aber m.E. good practice!
#Die Grössen der Arrays:
print(Xtrain.shape,Xtest.shape,ytrain.shape,ytest.shape)
print("Trainingsdaten")
display(ytrain.value_counts())
print("\nTestdaten")
display(ytest.value_counts())
print('\nKlassenverhältnis:')
#Von den Trainingsdaten gibt es in jeder Klasse etwa gleichviel mehr als in den Testdaten:
ytest.value_counts()/ytrain.value_counts()
# Out:
# (129, 2) (33, 2) (129,) (33,)
# Trainingsdaten
# Klassenlabel
# gabel-01           34
# messer-01          32
# korkenzieher-01    28
# loeffel-01         25
# trinkhalm-01       10
# Name: count, dtype: int64
# Testdaten
# Klassenlabel
# gabel-01           9
# messer-01          8
# korkenzieher-01    7
# loeffel-01         6
# trinkhalm-01       3
# Name: count, dtype: int64
# Klassenverhältnis:
# Klassenlabel
# gabel-01           0.264706
# messer-01          0.250000
# korkenzieher-01    0.250000
# loeffel-01         0.240000
# trinkhalm-01       0.300000
# Name: count, dtype: float64

# %% [markdown]
# Die Ausgaben oben zeigen die Anzahl Beispiele pro Klasse in den Training- und Testdaten sowie das Verhältnis pro Klasse. Das Verhältnis sollte für alle Klasse etwa gleich gross sein- dies nennt sich *stratifiziertes Training-Test-Splitten*.

# %%
display(Xtrain.head())
ytrain
# Out:
#                                             Dateiname  \
# 80  output/geschirr/1_object_extraction_output/Aus...
# 46  output/geschirr/1_object_extraction_output/Aus...
# 54  output/geschirr/1_object_extraction_output/Aus...
# 27  output/geschirr/1_object_extraction_output/Aus...
# 38  output/geschirr/1_object_extraction_output/Aus...
#
#                                             Basisname
# 80  output/geschirr/1_object_extraction_output/Aus...
# 46  output/geschirr/1_object_extraction_output/Aus...
# 54  output/geschirr/1_object_extraction_output/Aus...
# 27  output/geschirr/1_object_extraction_output/Aus...
# 38  output/geschirr/1_object_extraction_output/Aus...
# 80     korkenzieher-01
# 46          loeffel-01
# 54            gabel-01
# 27          loeffel-01
# 38            gabel-01
#             ...
# 134           gabel-01
# 151           gabel-01
# 139          messer-01
# 79     korkenzieher-01
# 90     korkenzieher-01
# Name: Klassenlabel, Length: 129, dtype: object

# %% [markdown]
# #### Shutil - High-level File Operations
# Wir kopieren nun die Daten in Unterordner von `pfad_zu_lcl_colab/2_Baumstruktur/`. Die Unterordner sollen die Klassennamen (Farben) sein.

# %%
import shutil
#Kopiere die Trainigsdaten
for Basisname,voller_Dateiname, label in zip(Xtrain.Basisname,Xtrain.Dateiname, ytrain):
    src = voller_Dateiname
    #dst = Path('/tmp','2_Baumstruktur',label)
    dst_train = Ausgabepfad/'2_Baumstruktur_train'/label

    dst_train.mkdir(exist_ok=True,parents=True)
    shutil.copy(src,dst_train/Basisname.name)
print(f"Trainingsdateien wurden nach {str(dst_train.parent)} kopiert.")
#Kopiere die Testdaten
for Basisname,voller_Dateiname, label in zip(Xtest.Basisname,Xtest.Dateiname, ytest):
    src = voller_Dateiname
    #dst = Path('/tmp','2_Baumstruktur',label)
    dst_test = Ausgabepfad/'2_Baumstruktur_test'/label

    dst_test.mkdir(exist_ok=True,parents=True)
    shutil.copy(src,dst_test/Basisname.name)
print(f"Testdateien wurden nach {str(dst_test.parent)} kopiert.")
# Out:
# Trainingsdateien wurden nach output/geschirr/1_object_extraction_output/2_Baumstruktur_train kopiert.
# Testdateien wurden nach output/geschirr/1_object_extraction_output/2_Baumstruktur_test kopiert.

# %% [markdown]
# Überprüfen wir die Struktur! Die Klassenverzeichnisse sind hier:

# %%
# !echo "Training-Baumstruktur:"
# !ls "{dst_train.parent}"
# !echo "Test-Baumstruktur:"
# !ls "{dst_test.parent}"
# Out:
# Training-Baumstruktur:
# gabel-01        korkenzieher-01 loeffel-01      messer-01       trinkhalm-01
# Test-Baumstruktur:
# gabel-01        korkenzieher-01 loeffel-01      messer-01       trinkhalm-01

# %% [markdown]
# Und darunter befinden sich die zur Klasse zugehörigen Bilder:

# %%
# !ls "{dst_test.parent}"/*
# Out:
# output/geschirr/1_object_extraction_output/2_Baumstruktur_test/gabel-01:
# gabel-01_0_9639.jpg gabel-01_0_9644.jpg gabel-01_0_9667.jpg gabel-01_0_9674.jpg
# gabel-01_0_9640.jpg gabel-01_0_9647.jpg gabel-01_0_9670.jpg
# gabel-01_0_9641.jpg gabel-01_0_9652.jpg gabel-01_0_9671.jpg
#
# output/geschirr/1_object_extraction_output/2_Baumstruktur_test/korkenzieher-01:
# korkenzieher-01_0_9702.jpg korkenzieher-01_0_9715.jpg
# korkenzieher-01_0_9707.jpg korkenzieher-01_0_9724.jpg
# korkenzieher-01_0_9708.jpg korkenzieher-01_0_9725.jpg
# korkenzieher-01_0_9712.jpg korkenzieher-01_0_9730.jpg
# korkenzieher-01_0_9714.jpg korkenzieher-01_0_9733.jpg
#
# output/geschirr/1_object_extraction_output/2_Baumstruktur_test/loeffel-01:
# loeffel-01_0_9508.jpg loeffel-01_0_9536.jpg loeffel-01_1_9533.jpg
# loeffel-01_0_9509.jpg loeffel-01_0_9540.jpg loeffel-01_1_9542.jpg
# loeffel-01_0_9514.jpg loeffel-01_0_9541.jpg loeffel-01_1_9546.jpg
# loeffel-01_0_9521.jpg loeffel-01_1_9505.jpg loeffel-01_2_9515.jpg
# loeffel-01_0_9522.jpg loeffel-01_1_9507.jpg loeffel-01_2_9531.jpg
# loeffel-01_0_9523.jpg loeffel-01_1_9508.jpg loeffel-01_2_9543.jpg
# loeffel-01_0_9525.jpg loeffel-01_1_9513.jpg loeffel-01_2_9545.jpg
# loeffel-01_0_9529.jpg loeffel-01_1_9515.jpg loeffel-01_2_9546.jpg
# loeffel-01_0_9531.jpg loeffel-01_1_9517.jpg
# loeffel-01_0_9534.jpg loeffel-01_1_9528.jpg
#
# output/geschirr/1_object_extraction_output/2_Baumstruktur_test/messer-01:
# messer-01_0_9547.jpg messer-01_0_9566.jpg messer-01_0_9581.jpg
# messer-01_0_9548.jpg messer-01_0_9567.jpg messer-01_0_9583.jpg
# messer-01_0_9549.jpg messer-01_0_9568.jpg messer-01_0_9584.jpg
# messer-01_0_9551.jpg messer-01_0_9569.jpg messer-01_1_9551.jpg
# messer-01_0_9553.jpg messer-01_0_9570.jpg messer-01_1_9553.jpg
# messer-01_0_9554.jpg messer-01_0_9572.jpg messer-01_1_9576.jpg
# messer-01_0_9556.jpg messer-01_0_9575.jpg messer-01_1_9581.jpg
# messer-01_0_9559.jpg messer-01_0_9578.jpg messer-01_1_9586.jpg
# messer-01_0_9563.jpg messer-01_0_9579.jpg messer-01_1_9587.jpg
# messer-01_0_9564.jpg messer-01_0_9580.jpg
#
# output/geschirr/1_object_extraction_output/2_Baumstruktur_test/trinkhalm-01:
# trinkhalm-01_0_9682.jpg trinkhalm-01_0_9691.jpg trinkhalm-01_1_9694.jpg
# trinkhalm-01_0_9687.jpg trinkhalm-01_0_9698.jpg trinkhalm-01_1_9697.jpg
# trinkhalm-01_0_9689.jpg trinkhalm-01_1_9684.jpg trinkhalm-01_1_9699.jpg

# %% [markdown]
# Nun wollen wir diese zwei Baumstrukturen herunterladen:

# %%
from IPython.display import FileLink
! echo "-Trainingdaten-"
! zip -r training_Baumstruktur.zip {dst_train.parent}/*|tail -n5
! echo "-Testdaten-"
! zip -r testing_Baumstruktur.zip {dst_test.parent}/*|tail -n5
# Out:
# -Trainingdaten-
# updating: output/geschirr/1_object_extraction_output/2_Baumstruktur_train/trinkhalm-01/trinkhalm-01_1_9686.jpg (deflated 9%)
# updating: output/geschirr/1_object_extraction_output/2_Baumstruktur_train/trinkhalm-01/trinkhalm-01_1_9685.jpg (deflated 10%)
# updating: output/geschirr/1_object_extraction_output/2_Baumstruktur_train/trinkhalm-01/trinkhalm-01_1_9683.jpg (deflated 8%)
# updating: output/geschirr/1_object_extraction_output/2_Baumstruktur_train/trinkhalm-01/trinkhalm-01_1_9688.jpg (deflated 9%)
#   adding: output/geschirr/1_object_extraction_output/2_Baumstruktur_train/trinkhalm-01/trinkhalm-01_1_9684.jpg (deflated 9%)
# -Testdaten-
#   adding: output/geschirr/1_object_extraction_output/2_Baumstruktur_test/messer-01/messer-01_1_9586.jpg (deflated 6%)
#   adding: output/geschirr/1_object_extraction_output/2_Baumstruktur_test/messer-01/messer-01_1_9587.jpg (deflated 7%)
#   adding: output/geschirr/1_object_extraction_output/2_Baumstruktur_test/messer-01/messer-01_0_9564.jpg (deflated 11%)
#   adding: output/geschirr/1_object_extraction_output/2_Baumstruktur_test/messer-01/messer-01_0_9563.jpg (deflated 11%)
#   adding: output/geschirr/1_object_extraction_output/2_Baumstruktur_test/trinkhalm-01/trinkhalm-01_0_9689.jpg (deflated 6%)

# %% [markdown]
# Die folgenden Ausgaben geben einen Link an. Bitte klicken Sie ihn an und speichern Sie die .zip-Datei lokal ab. Sie sollten sie anschliessend extrahieren und überprüfen, ob die Baumstruktur stimmt.

# %%
FileLink(r'training_Baumstruktur.zip')
# Out:
# /Users/user/ws/py/imageclassify/training_Baumstruktur.zip

# %%
FileLink(r'testing_Baumstruktur.zip')
# Out:
# /Users/user/ws/py/imageclassify/testing_Baumstruktur.zip

# %% [markdown]
# **Gratulation!!!** Damit sind wir bereit für das Training eines neuronalen Netzes. Weiter geht's im Notebook `2_training/Training.ipynb.
